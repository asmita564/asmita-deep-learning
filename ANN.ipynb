# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
import pandas as pd
import io
data = pd.read_csv(io.StringIO(uploaded['data.csv'].decode('utf-8')))
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#del data['Unnamed: 32']

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
x = data.iloc[:, 2:]
y = data.iloc[:, 1]

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
# from sklearn.preprocessing import LabelEncoder
# labelencoder_x_1 = LabelEncoder()
# y = labelencoder_x_1.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_tain, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(x_tain,y_train)
# Out:
# RandomForestClassifier()

# %%
pred=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[64,  3],
#        [ 1, 46]])

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9649122807017544

# %%
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.layers import Dropout
classifier = Sequential()

# %%
classifier.add(Dense(16, activation='relu', kernel_initializer='glorot_uniform',input_dim=30))

# %%
classifier.add(Dense(16, activation='relu', kernel_initializer='glorot_uniform'))

# %%
classifier.add(Dense(2,kernel_initializer='glorot_uniform', activation='sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 16)                496
#
#  dense_5 (Dense)             (None, 16)                272
#
#  dense_6 (Dense)             (None, 2)                 34
#
# ...
# Total params: 802
# Trainable params: 802
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(y_train)
encoded_Y = encoder.transform(y_train)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)

# %%
#Compiling ANN
classifier.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])

# %%
#Fitting ANN
classifier.fit(x_tain,dummy_y,batch_size=3,epochs = 100)
# Out:
# Epoch 1/100
# 152/152 [==============================] - 0s 3ms/step - loss: 0.2263 - accuracy: 0.9231
# Epoch 2/100
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1980 - accuracy: 0.9253
# Epoch 3/100
# 152/152 [==============================] - 0s 3ms/step - loss: 0.2029 - accuracy: 0.9319
# Epoch 4/100
# 152/152 [==============================] - 1s 4ms/step - loss: 0.2009 - accuracy: 0.9363
# Epoch 5/100
# 152/152 [==============================] - 0s 3ms/step - loss: 0.1599 - accuracy: 0.9407
# Epoch 6/100
# 152/152 [==============================] - 0s 2ms/step - loss: 0.2040 - accuracy: 0.9341
# Epoch 7/100
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9319
# Epoch 8/100
# 152/152 [==============================] - 0s 2ms/step - loss: 0.2161 - accuracy: 0.9231
# Epoch 9/100
# 152/152 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9495
# Epoch 10/100
# ...
